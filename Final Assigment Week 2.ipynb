# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Introduction/Business Problem
# ### Many tourists over the globe have been affected by insecurity when visiting places on other cities, this due to the fact the tourist does not have information about the most common places where crimes are performed. According to this the tourism and the people affected annually loses a lot of many and time.
# ### Infotou is a data application that deliveries the tourist all information regarding to venues and the security around them, this would help tourists to make good decisions and to have a better vacation around the global cities.

# %% [markdown]
# ## Data
# ### To perform Infotou the following data would be used:
# •	Foursquare location data, in order to have all venues from the city of San Francisco
# •	Data base of crimes in the city of San Francisco.
# ### An example of this is that Infotou will obtain the most popular places in San Francisco and check the crimes around this specific venue, according to this Infotou will calculate the number of crimes around it and make a cluster for the venues (High Risk, medium risk & Low Risk).Infotou will be able to give the user a visualization by colors of the most risky venues.

# %% [markdown]
# ##### Installations and imports for the project

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ###### First Step: Create data frame of crimes and clean the data

# %%
df_incidents = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Police_Department_Incidents_-_Previous_Year__2016_.csv')

# %% [markdown]
# ###### Drop all the unnecesary information

# %%
df_incidents.drop(df_incidents[df_incidents.Category == "WEAPON LAWS"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "WARRANTS"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "MISSING PERSON"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "STOLEN PROPERTY"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "RECOVERED VEHICLE"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "ARSON"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "SECONDARY CODES"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "RUNAWAY"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "FAMILY OFFENSES"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "SUICIDE"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "LIQUOR LAWS"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "LOITERING"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "TREA"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "BAD CHECKS"].index, inplace=True)
df_incidents.drop(df_incidents[df_incidents.Category == "PORNOGRAPHY/OBSCENE MAT"].index, inplace=True)
df_incidents.head()
# Out:
#    IncidntNum        Category          Descript DayOfWeek  \
# 3   160013662    NON-CRIMINAL     LOST PROPERTY   Tuesday
# 4   160002740    NON-CRIMINAL     LOST PROPERTY    Friday
# 5   160002869         ASSAULT           BATTERY    Friday
# 6   160003130  OTHER OFFENSES  PAROLE VIOLATION  Saturday
# 7   160003259    NON-CRIMINAL       FIRE REPORT  Saturday
#
#                      Date   Time  PdDistrict      Resolution  \
# 3  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
# 5  01/01/2016 12:00:00 AM  21:35    NORTHERN            NONE
# 6  01/02/2016 12:00:00 AM  00:04    SOUTHERN  ARREST, BOOKED
# 7  01/02/2016 12:00:00 AM  01:02  TENDERLOIN            NONE
#
#                   Address           X          Y  \
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
# 5   1700 Block of BUSH ST -122.426077  37.788019
# 6     MARY ST / HOWARD ST -122.405721  37.780879
# 7    200 Block of EDDY ST -122.411778  37.783981
#
#                                 Location            PdId
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000
# 5   (37.788018555829, -122.426077177375)  16000286904134
# 6  (37.7808789360214, -122.405721454567)  16000313026150
# 7  (37.7839805592634, -122.411778295992)  16000325968000

# %%
df_incidents.shape
# Out:
# (134344, 13)

# %% [markdown]
# ##### San Francisco Coordinates & limit of 1000 due to computation resources

# %%
#San Francisco Coordinates
latitude = 37.77
longitude = -122.42
limit = 1000
df_incidents = df_incidents.iloc[0:limit, :]
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)
#Only showing 1000 crimes due to computation

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 1000 crimes and add each to the incidents feature group
for lat, lng, in zip(df_incidents.Y, df_incidents.X):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Foursquare credentials

# %%
CLIENT_ID = '1TPUE0CMO2FBONJ5C13PW1DSGWMNJJSTGZKY34PTOC1R0I3U' # your Foursquare ID
CLIENT_SECRET = '0WKMNH2PP34KYM30F3K4QNGKBYM4UWH4PH25CQYVRSOC2ODI' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1TPUE0CMO2FBONJ5C13PW1DSGWMNJJSTGZKY34PTOC1R0I3U
# CLIENT_SECRET:0WKMNH2PP34KYM30F3K4QNGKBYM4UWH4PH25CQYVRSOC2ODI

# %%
address = 'San Francisco, SF'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.7790262 -122.4199061

# %% [markdown]
# ##### We only work with venues related to food in order to have less computation and less time for computation

# %%
search_query = 'Food'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1TPUE0CMO2FBONJ5C13PW1DSGWMNJJSTGZKY34PTOC1R0I3U&client_secret=0WKMNH2PP34KYM30F3K4QNGKBYM4UWH4PH25CQYVRSOC2ODI&ll=37.7790262,-122.4199061&v=20180605&query=Food&radius=2000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb31e351a4b0a0028428b5f'},
#  'response': {'venues': [{'id': '49f356f8f964a5208a6a1fe3',
#     'name': "Brenda's French Soul Food",
#     'location': {'address': '652 Polk St',
#      'crossStreet': 'btwn Eddy & Turk St',
#      'lat': 37.782896409128426,
#      'lng': -122.41889744997026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782896409128426,
#        'lng': -122.41889744997026},
#       {'label': 'entrance', 'lat': 37.782891, 'lng': -122.419019}],
#      'distance': 439,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['652 Polk St (btwn Eddy & Turk St)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14f941735',
#       'name': 'Southern / Soul Food Restaurant',
#       'pluralName': 'Southern / Soul Food Restaurants',
#       'shortName': 'Southern / Soul',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4a3f0ce4f964a520aca31fe3',
#     'name': 'Pet Food Express',
#     'location': {'address': '1975 Market St',
#      'crossStreet': '(Between Duboce & Dolores)',
#      'lat': 37.76923879073783,
#      'lng': -122.42627112387855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76923879073783,
#        'lng': -122.42627112387855}],
#      'distance': 1225,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1975 Market St ((Between Duboce & Dolores))',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'shortName': 'Pet Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '49d7ae4bf964a5204b5d1fe3',
#     'name': 'Real Food Company',
#     'location': {'address': '2140 Polk St',
#      'crossStreet': 'at Broadway',
#      'lat': 37.7965779,
#      'lng': -122.4216322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.7965779,
#        'lng': -122.4216322},
#       {'label': 'entrance', 'lat': 37.796555, 'lng': -122.421784}],
#      'distance': 1959,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2140 Polk St (at Broadway)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4fc7c071e4b06e4ecff8e93d',
#     'name': 'SoMa StrEat Food Park',
#     'location': {'address': '428 11th St',
#      'crossStreet': 'at Division St',
#      'lat': 37.76964417224087,
#      'lng': -122.41175489448761,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76964417224087,
#        'lng': -122.41175489448761}],
#      'distance': 1266,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St (at Division St)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48660680'},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '52f934d711d2f1eaaa247732',
#     'name': 'Costco Food Court',
#     'location': {'address': '450 10th St',
#      'crossStreet': 'Near Bryant St',
#      'lat': 37.77076041176799,
#      'lng': -122.4106157539553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77076041176799,
#        'lng': -122.4106157539553}],
#      'distance': 1230,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['450 10th St (Near Bryant St)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4a0c9b12f964a5204a751fe3',
#     'name': 'Buffalo Whole Food & Grain Co',
#     'location': {'address': '598 Castro St',
#      'crossStreet': 'at 19th St',
#      'lat': 37.75937356479043,
#      'lng': -122.43495459732968,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.75937356479043,
#        'lng': -122.43495459732968},
#       {'label': 'entrance', 'lat': 37.759387, 'lng': -122.435016}],
#      'distance': 2557,
#      'postalCode': '94114',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['598 Castro St (at 19th St)',
#       'San Francisco, CA 94114',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4da62cc4fa8c94f8b8498322',
#     'name': 'The Food Emporium',
#     'location': {'address': '865 Market St',
#      'crossStreet': 'in Westfield San Francisco Centre',
#      'lat': 37.78462493600286,
#      'lng': -122.40665390885398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78462493600286,
#        'lng': -122.40665390885398}],
#      'distance': 1322,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['865 Market St (in Westfield San Francisco Centre)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4b71d0cbf964a5200c5e2de3',
#     'name': 'Van Ness Food Co.',
#     'location': {'address': '1356 Van Ness Ave',
#      'crossStreet': 'Bush',
#      'lat': 37.788396,
#      'lng': -122.421618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.788396,
#        'lng': -122.421618},
#       {'label': 'entrance', 'lat': 37.78838, 'lng': -122.421719}],
#      'distance': 1053,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1356 Van Ness Ave (Bush)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '5b73278110b3030024bb3c10',
#     'name': 'Food Truck Lane',
#     'location': {'address': 'Natoma St',
#      'crossStreet': 'Howard St',
#      'lat': 37.78761639932625,
#      'lng': -122.39784859563576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78761639932625,
#        'lng': -122.39784859563576}],
#      'distance': 2163,
#      'postalCode': '94105',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Natoma St (Howard St)',
#       'San Francisco, CA 94105',
#       'United States']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '49d12401f964a5205f5b1fe3',
#     'name': 'Caramba Mexican Food',
#     'location': {'address': '78 2nd St',
#      'crossStreet': 'Mission St',
#      'lat': 37.78832015506857,
#      'lng': -122.40009446586305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78832015506857,
#        'lng': -122.40009446586305},
#       {'label': 'entrance', 'lat': 37.788248, 'lng': -122.400286}],
#      'distance': 2026,
#      'postalCode': '94105',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['78 2nd St (Mission St)',
#       'San Francisco, CA 94105',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '532900f2498e2489a4ce9877',
#     'name': 'Gauntlet Food Truck',
#     'location': {'address': '843 Mission St',
#      'crossStreet': '5th Street',
#      'lat': 37.78337,
#      'lng': -122.405077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78337,
#        'lng': -122.405077}],
#      'distance': 1391,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['843 Mission St (5th Street)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '49e4bd65f964a52029631fe3',
#     'name': 'Foods Co',
#     'location': {'address': '1800 Folsom St',
#      'crossStreet': 'at 14th St',
#      'lat': 37.767611012436255,
#      'lng': -122.41612406107379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.767611012436255,
#        'lng': -122.41612406107379}],
#      'distance': 1313,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1800 Folsom St (at 14th St)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4febb844e4b0180507ce8ad0',
#     'name': "Taqueria Angelica's Truck @ SOMA Streat Food Park",
#     'location': {'address': '428 11th St',
#      'crossStreet': '13th Street',
#      'lat': 37.786367233534115,
#      'lng': -122.40633391482605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.786367233534115,
#        'lng': -122.40633391482605}],
#      'distance': 1446,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St (13th Street)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '45fa7840f964a52053441fe3',
#     'name': 'Food Fair Market Liquors',
#     'location': {'address': '611 Bush St',
#      'crossStreet': 'Stockton St',
#      'lat': 37.79031294360036,
#      'lng': -122.407371984541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.79031294360036,
#        'lng': -122.407371984541},
#       {'label': 'entrance', 'lat': 37.79025, 'lng': -122.407417}],
#      'distance': 1671,
#      'postalCode': '94108',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['611 Bush St (Stockton St)',
#       'San Francisco, CA 94108',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '465c2776f964a5202d471fe3',
#     'name': 'Sears Fine Food',
#     'location': {'address': '439 Powell St',
#      'crossStreet': 'btwn Sutter & Post',
#      'lat': 37.78886944537694,
#      'lng': -122.40853796464017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78886944537694,
#        'lng': -122.40853796464017}],
#      'distance': 1483,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['439 Powell St (btwn Sutter & Post)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '37507352'},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4ec5af192c5b532d049042d4',
#     'name': 'Food-Nerd',
#     'location': {'address': '842 California St',
#      'crossStreet': 'just East of Powell',
#      'lat': 37.79225958986612,
#      'lng': -122.40840259157181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.79225958986612,
#        'lng': -122.40840259157181},
#       {'label': 'entrance', 'lat': 37.792253, 'lng': -122.408443}],
#      'distance': 1787,
#      'postalCode': '94108',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['842 California St (just East of Powell)',
#       'San Francisco, CA 94108',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '57746b60498ea064178a9fe8',
#     'name': 'Foodhall',
#     'location': {'address': '3100 16th St',
#      'crossStreet': 'at Valencia St',
#      'lat': 37.76503546402145,
#      'lng': -122.42198701446608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76503546402145,
#        'lng': -122.42198701446608}],
#      'distance': 1568,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3100 16th St (at Valencia St)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '58e0358edfa6ff63a9e0f234',
#     'name': 'Woori Food Market',
#     'location': {'address': '1528 Fillmore St',
#      'lat': 37.78375924658761,
#      'lng': -122.43274762260802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78375924658761,
#        'lng': -122.43274762260802}],
#      'distance': 1246,
#      'postalCode': '94115',
#      'cc': 'US',
#      'neighborhood': 'Fillmore District',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1528 Fillmore St',
#       'San Francisco, CA 94115',
#       'United States']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1278315',
#      'url': 'https://www.grubhub.com/restaurant/woori-market-1528-fillmore-st-san-francisco/1278315?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1278315',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4c325dd83896e21e6d6ee890',
#     'name': 'Mission Chinese Food',
#     'location': {'address': '2234 Mission St',
#      'crossStreet': 'btwn 18th & 19th St',
#      'lat': 37.76118615249867,
#      'lng': -122.41939496055302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76118615249867,
#        'lng': -122.41939496055302},
#       {'label': 'entrance', 'lat': 37.761196, 'lng': -122.419454}],
#      'distance': 1986,
#      'postalCode': '94110',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2234 Mission St (btwn 18th & 19th St)',
#       'San Francisco, CA 94110',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '291936',
#      'url': 'https://www.grubhub.com/restaurant/mission-chinese-food-2234-mission-st-san-francisco/291936?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=291936',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4f32752419836c91c7d9b88f',
#     'name': 'Food Trattoria',
#     'location': {'address': '2800 California St',
#      'lat': 37.788166,
#      'lng': -122.44065,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.788166,
#        'lng': -122.44065}],
#      'distance': 2089,
#      'postalCode': '94115',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2800 California St',
#       'San Francisco, CA 94115',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4cdf5d9cf8a4a1431c26debc',
#     'name': 'Food Trucks On Valencia',
#     'location': {'lat': 37.77643018833841,
#      'lng': -122.41701426544748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77643018833841,
#        'lng': -122.41701426544748}],
#      'distance': 385,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94103', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4d66f3459792b1f7f920381f',
#     'name': "Mad Will's Food Company",
#     'location': {'address': '450 Gough St',
#      'crossStreet': 'Ivy',
#      'lat': 37.777614,
#      'lng': -122.42279099999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.777614,
#        'lng': -122.42279099999999}],
#      'distance': 298,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['450 Gough St (Ivy)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4d138e7ad0508eec3681c034',
#     'name': 'Super Sam Food',
#     'location': {'address': '691 McAllister St',
#      'crossStreet': 'at Gough',
#      'lat': 37.77987957394827,
#      'lng': -122.422754989151,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77987957394827,
#        'lng': -122.422754989151}],
#      'distance': 268,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['691 McAllister St (at Gough)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '504bc25afe703cf447d07441',
#     'name': 'Streets Eat Street Food',
#     'location': {'address': '634 Polk St',
#      'crossStreet': 'Eddy St',
#      'lat': 37.782734999999995,
#      'lng': -122.418878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782734999999995,
#        'lng': -122.418878},
#       {'label': 'entrance', 'lat': 37.782684, 'lng': -122.418986}],
#      'distance': 422,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['634 Polk St (Eddy St)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '502e677fe4b0c65b4a47ebd5',
#     'name': 'Federal Bldg Food Court',
#     'location': {'lat': 37.78238948486344,
#      'lng': -122.42076955277753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78238948486344,
#        'lng': -122.42076955277753}],
#      'distance': 382,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4bd34559462cb713c601de07',
#     'name': 'IVYS Food Co,',
#     'location': {'address': '1216 Stockton St',
#      'lat': 37.797028000000005,
#      'lng': -122.40827900000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.797028000000005,
#        'lng': -122.40827900000001},
#       {'label': 'entrance', 'lat': 37.797014, 'lng': -122.408387}],
#      'distance': 2249,
#      'postalCode': '94133',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1216 Stockton St',
#       'San Francisco, CA 94133',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '57a215af498ee734214d5257',
#     'name': 'Good Food Guys HQ',
#     'location': {'address': '563 Clay St',
#      'lat': 37.794588,
#      'lng': -122.402672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.794588,
#        'lng': -122.402672},
#       {'label': 'entrance', 'lat': 37.794674, 'lng': -122.402666}],
#      'distance': 2302,
#      'postalCode': '94111',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['563 Clay St',
#       'San Francisco, CA 94111',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '50762a57e4b009da37e478f9',
#     'name': 'Hongry Kong @ Soma StrEat Food Park',
#     'location': {'lat': 37.77511659319176,
#      'lng': -122.41821442342173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77511659319176,
#        'lng': -122.41821442342173}],
#      'distance': 459,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94103', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '56df2a4bcd10992fe619f399',
#     'name': 'WoKitchen Food Truck',
#     'location': {'lat': 37.77994,
#      'lng': -122.41436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77994,
#        'lng': -122.41436}],
#      'distance': 498,
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108941735',
#       'name': 'Dumpling Restaurant',
#       'pluralName': 'Dumpling Restaurants',
#       'shortName': 'Dumplings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4f3c61e9e4b00d955e59119f',
#     'name': 'Taco Guys food truck @ Off The Grid: Proxy',
#     'location': {'lat': 37.7763557434082,
#      'lng': -122.42405700683594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.7763557434082,
#        'lng': -122.42405700683594}],
#      'distance': 470,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4e832a816d86be34609b6057',
#     'name': 'Ready To Nosh Food Tours',
#     'location': {'address': 'Corner of Hyde and market',
#      'crossStreet': 'hyde and market',
#      'lat': 37.77880498241423,
#      'lng': -122.4148178100586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77880498241423,
#        'lng': -122.4148178100586}],
#      'distance': 448,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Corner of Hyde and market (hyde and market)',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '50f32b0ee4b0dba1e361bd99',
#     'name': 'Mercato Artisan Food & Gifts',
#     'location': {'lat': 37.799122885556635,
#      'lng': -122.40854661251785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.799122885556635,
#        'lng': -122.40854661251785}],
#      'distance': 2450,
#      'postalCode': '94133',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94133', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '52d4eeb511d2a567cf36250e',
#     'name': 'Savourie Streets @ SOMA StrEat Food Park',
#     'location': {'address': '428 11th St',
#      'lat': 37.770905623808304,
#      'lng': -122.41096349061215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.770905623808304,
#        'lng': -122.41096349061215}],
#      'distance': 1198,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '52ae58e8498ebee9cb2513d8',
#     'name': 'Soul Food City',
#     'location': {'address': '403 Eddy St',
#      'crossStreet': 'at Leavenworth St',
#      'lat': 37.783910194909815,
#      'lng': -122.41460837751777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.783910194909815,
#        'lng': -122.41460837751777},
#       {'label': 'entrance', 'lat': 37.78361, 'lng': -122.414494}],
#      'distance': 716,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['403 Eddy St (at Leavenworth St)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14f941735',
#       'name': 'Southern / Soul Food Restaurant',
#       'pluralName': 'Southern / Soul Food Restaurants',
#       'shortName': 'Southern / Soul',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '313797',
#      'url': 'https://www.grubhub.com/restaurant/soul-food-city-403-eddy-st-san-francisco/313797?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=313797',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4f326e6c19836c91c7d72927',
#     'name': 'Southeast Asian Food Product',
#     'location': {'address': '541 Eddy St',
#      'lat': 37.783332,
#      'lng': -122.416912,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.783332,
#        'lng': -122.416912}],
#      'distance': 546,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['541 Eddy St',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4be0f9d90365c9b65bacb238',
#     'name': 'Food And Wine SF',
#     'location': {'address': '239 8th St',
#      'lat': 37.775649,
#      'lng': -122.41109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.775649,
#        'lng': -122.41109},
#       {'label': 'entrance', 'lat': 37.775849, 'lng': -122.410947}],
#      'distance': 861,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['239 8th St',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4f32b06c19836c91c7f01a52',
#     'name': 'Kim Hoang Coffee and Fast Food',
#     'location': {'address': '246 Leavenworth St',
#      'lat': 37.78355,
#      'lng': -122.414025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78355,
#        'lng': -122.414025},
#       {'label': 'entrance', 'lat': 37.783541, 'lng': -122.414098}],
#      'distance': 722,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['246 Leavenworth St',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4fc7cbbfe4b0fd7896eec75d',
#     'name': 'Brass Knuckle @ SOMA StreatFood Park',
#     'location': {'address': '428 11th St',
#      'crossStreet': 'Division Street',
#      'lat': 37.77040128588444,
#      'lng': -122.41275552971678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77040128588444,
#        'lng': -122.41275552971678}],
#      'distance': 1147,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St (Division Street)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4d7bfa115a396dcb4d436bfb',
#     'name': 'T&L Food Market',
#     'location': {'address': '405 Eddy St',
#      'crossStreet': 'Leavenworth',
#      'lat': 37.783567,
#      'lng': -122.414484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.783567,
#        'lng': -122.414484}],
#      'distance': 695,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['405 Eddy St (Leavenworth)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '56d788e2498ee3fdf1c34215',
#     'name': 'Chevron Food Mart',
#     'location': {'address': '1298 Howard St',
#      'lat': 37.775508,
#      'lng': -122.41325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.775508,
#        'lng': -122.41325}],
#      'distance': 704,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1298 Howard St',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '5425cbf5498e72832b28b015',
#     'name': 'Thali on Wheels Food Truck',
#     'location': {'address': '428 11th St',
#      'lat': 37.77583120194724,
#      'lng': -122.41215265577499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77583120194724,
#        'lng': -122.41215265577499}],
#      'distance': 769,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4f32ab2919836c91c7ee27a4',
#     'name': 'Nathan and Nathalie Fast Food',
#     'location': {'address': '393 Eddy St',
#      'lat': 37.78377,
#      'lng': -122.414012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78377,
#        'lng': -122.414012}],
#      'distance': 740,
#      'postalCode': '94102',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['393 Eddy St',
#       'San Francisco, CA 94102',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4b97cdc0f964a520a01635e3',
#     'name': 'Food & Liquor World',
#     'location': {'address': '728 Post St',
#      'crossStreet': 'btw Jones & Leavenworth',
#      'lat': 37.78768479623101,
#      'lng': -122.41392527258829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78768479623101,
#        'lng': -122.41392527258829}],
#      'distance': 1098,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['728 Post St (btw Jones & Leavenworth)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2065054',
#      'url': 'https://www.grubhub.com/restaurant/food--liquor-world-726-28-post-street-san-francisco/2065054?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2065054',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '5054f32ee4b07ab78d3c6d84',
#     'name': "Kinder's BBQ Food Truck",
#     'location': {'address': '2239 Morello Ave',
#      'lat': 37.77182388305664,
#      'lng': -122.42280578613281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77182388305664,
#        'lng': -122.42280578613281}],
#      'distance': 841,
#      'postalCode': '94523',
#      'cc': 'US',
#      'city': 'Pleasant Hill',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2239 Morello Ave',
#       'Pleasant Hill, CA 94523',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4a2df818f964a5200d981fe3',
#     'name': 'Yogi Food Market',
#     'location': {'address': '908 Sutter St',
#      'crossStreet': 'at Leavenworth St',
#      'lat': 37.78834263799417,
#      'lng': -122.41538205652019,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78834263799417,
#        'lng': -122.41538205652019},
#       {'label': 'entrance', 'lat': 37.788462, 'lng': -122.415375}],
#      'distance': 1110,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['908 Sutter St (at Leavenworth St)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4ee3af0493adf8e1a6e78ad0',
#     'name': 'Veritas Food Truck',
#     'location': {'lat': 37.771705627441406,
#      'lng': -122.422607421875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.771705627441406,
#        'lng': -122.422607421875}],
#      'distance': 848,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['San Francisco, CA 94103', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '5025567ee4b0c6da26677c3c',
#     'name': 'Mama Cass @ Soma StrEat Food Park',
#     'location': {'address': '428 11th St',
#      'crossStreet': 'Division St.',
#      'lat': 37.77084503105942,
#      'lng': -122.4107367180533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.77084503105942,
#        'lng': -122.4107367180533}],
#      'distance': 1216,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['428 11th St (Division St.)',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '4af9d536f964a520981422e3',
#     'name': "Little Henry's Italian Food",
#     'location': {'address': '955 Larkin St',
#      'crossStreet': 'btw Cedar St & Post St',
#      'lat': 37.78701721027501,
#      'lng': -122.4184196763512,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78701721027501,
#        'lng': -122.4184196763512},
#       {'label': 'entrance', 'lat': 37.7869, 'lng': -122.418382}],
#      'distance': 899,
#      'postalCode': '94109',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['955 Larkin St (btw Cedar St & Post St)',
#       'San Francisco, CA 94109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '51523e4ae4b0e54f40cc6958',
#     'name': "Jeffrey's Natural Pet Food",
#     'location': {'address': '284 Noe St',
#      'crossStreet': 'Market St',
#      'lat': 37.76444377194593,
#      'lng': -122.43310666544639,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.76444377194593,
#        'lng': -122.43310666544639},
#       {'label': 'entrance', 'lat': 37.764549, 'lng': -122.433273}],
#      'distance': 1996,
#      'postalCode': '94114',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['284 Noe St (Market St)',
#       'San Francisco, CA 94114',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'shortName': 'Pet Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588796840',
#     'hasPerk': False},
#    {'id': '5c7599094acb19002bbc1726',
#     'name': 'golden gate halal food',
#     'location': {'address': '979 Market St',
#      'lat': 37.782475,
#      'lng': -122.409757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.782475,
#        'lng': -122.409757},
#       {'label': 'entrance', 'lat': 37.782519, 'lng': -122.40966}],
#      'distance': 971,
#      'postalCode': '94103',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['979 Market St',
#       'San Francisco, CA 94103',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'shortName': 'Halal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1128017',
#      'url': 'https://www.grubhub.com/restaurant/golden-gate-halal-food-979-market-st-san-francisco/1128017?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1128017',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1588796840',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                       name  \
# 0  49f356f8f964a5208a6a1fe3  Brenda's French Soul Food
# 1  4a3f0ce4f964a520aca31fe3           Pet Food Express
# 2  49d7ae4bf964a5204b5d1fe3          Real Food Company
# 3  4fc7c071e4b06e4ecff8e93d      SoMa StrEat Food Park
# 4  52f934d711d2f1eaaa247732          Costco Food Court
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14f941735', 'name': 'S...  v-1588796840    False
# 1  [{'id': '4bf58dd8d48988d100951735', 'name': 'P...  v-1588796840    False
# 2  [{'id': '52f2ab2ebcbc57f1066b8b45', 'name': 'O...  v-1588796840    False
# 3  [{'id': '53e0feef498e5aac066fd8a9', 'name': 'S...  v-1588796840    False
# 4  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1588796840    False
#
#   location.address        location.crossStreet  location.lat  location.lng  \
# 0      652 Polk St         btwn Eddy & Turk St     37.782896   -122.418897
# 1   1975 Market St  (Between Duboce & Dolores)     37.769239   -122.426271
# 2     2140 Polk St                 at Broadway     37.796578   -122.421632
# 3      428 11th St              at Division St     37.769644   -122.411755
# 4      450 10th St              Near Bryant St     37.770760   -122.410616
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 37.78289640912842...                439
# 1  [{'label': 'display', 'lat': 37.76923879073783...               1225
# 2  [{'label': 'display', 'lat': 37.7965779, 'lng'...               1959
# 3  [{'label': 'display', 'lat': 37.76964417224087...               1266
# 4  [{'label': 'display', 'lat': 37.77076041176799...               1230
#
#   location.postalCode location.cc  location.city location.state  \
# 0               94102          US  San Francisco             CA
# 1               94103          US  San Francisco             CA
# 2               94109          US  San Francisco             CA
# 3               94103          US  San Francisco             CA
# 4               94103          US  San Francisco             CA
#
#   location.country                          location.formattedAddress  \
# 0    United States  [652 Polk St (btwn Eddy & Turk St), San Franci...
# 1    United States  [1975 Market St ((Between Duboce & Dolores)), ...
# 2    United States  [2140 Polk St (at Broadway), San Francisco, CA...
# 3    United States  [428 11th St (at Division St), San Francisco, ...
# 4    United States  [450 10th St (Near Bryant St), San Francisco, ...
#
#   venuePage.id location.neighborhood delivery.id delivery.url  \
# 0          NaN                   NaN         NaN          NaN
# 1          NaN                   NaN         NaN          NaN
# 2          NaN                   NaN         NaN          NaN
# 3     48660680                   NaN         NaN          NaN
# 4          NaN                   NaN         NaN          NaN
#
#   delivery.provider.name delivery.provider.icon.prefix  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                           Brenda's French Soul Food
# 1                                    Pet Food Express
# 2                                   Real Food Company
# 3                               SoMa StrEat Food Park
# 4                                   Costco Food Court
# 5                       Buffalo Whole Food & Grain Co
# 6                                   The Food Emporium
# 7                                   Van Ness Food Co.
# 8                                     Food Truck Lane
# 9                                Caramba Mexican Food
# 10                                Gauntlet Food Truck
# 11                                           Foods Co
# 12  Taqueria Angelica's Truck @ SOMA Streat Food Park
# 13                           Food Fair Market Liquors
# 14                                    Sears Fine Food
# 15                                          Food-Nerd
# 16                                           Foodhall
# 17                                  Woori Food Market
# 18                               Mission Chinese Food
# 19                                     Food Trattoria
# 20                            Food Trucks On Valencia
# 21                            Mad Will's Food Company
# 22                                     Super Sam Food
# 23                            Streets Eat Street Food
# 24                            Federal Bldg Food Court
# 25                                      IVYS Food Co,
# 26                                  Good Food Guys HQ
# 27                Hongry Kong @ Soma StrEat Food Park
# 28                               WoKitchen Food Truck
# 29         Taco Guys food truck @ Off The Grid: Proxy
# 30                           Ready To Nosh Food Tours
# 31                       Mercato Artisan Food & Gifts
# 32           Savourie Streets @ SOMA StrEat Food Park
# 33                                     Soul Food City
# 34                       Southeast Asian Food Product
# 35                                   Food And Wine SF
# 36                     Kim Hoang Coffee and Fast Food
# 37               Brass Knuckle @ SOMA StreatFood Park
# 38                                    T&L Food Market
# 39                                  Chevron Food Mart
# 40                         Thali on Wheels Food Truck
# 41                      Nathan and Nathalie Fast Food
# 42                                Food & Liquor World
# 43                            Kinder's BBQ Food Truck
# 44                                   Yogi Food Market
# 45                                 Veritas Food Truck
# 46                  Mama Cass @ Soma StrEat Food Park
# 47                        Little Henry's Italian Food
# 48                         Jeffrey's Natural Pet Food
# 49                             golden gate halal food
#
#                          categories                    address  \
# 0   Southern / Soul Food Restaurant                652 Polk St
# 1                         Pet Store             1975 Market St
# 2                   Organic Grocery               2140 Polk St
# 3             Street Food Gathering                428 11th St
# 4                        Food Court                450 10th St
# 5                     Grocery Store              598 Castro St
# 29                                NaN  37.776356 -122.424057
# 30                    hyde and market  37.778805 -122.414818
# 31                                NaN  37.799123 -122.408547
# 32                                NaN  37.770906 -122.410963
# 33                  at Leavenworth St  37.783910 -122.414608
# 34                                NaN  37.783332 -122.416912
# 35                                NaN  37.775649 -122.411090
# 36                                NaN  37.783550 -122.414025
# 37                    Division Street  37.770401 -122.412756
# 38                        Leavenworth  37.783567 -122.414484
# 39                                NaN  37.775508 -122.413250
# 40                                NaN  37.775831 -122.412153
# 41                                NaN  37.783770 -122.414012
# 42            btw Jones & Leavenworth  37.787685 -122.413925
# 43                                NaN  37.771824 -122.422806
# 44                  at Leavenworth St  37.788343 -122.415382
# 45                                NaN  37.771706 -122.422607
# 46                       Division St.  37.770845 -122.410737
# 47             btw Cedar St & Post St  37.787017 -122.418420
# 48                          Market St  37.764444 -122.433107
# 49                                NaN  37.782475 -122.409757
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 37.78289640912842...       439      94102
# 1   [{'label': 'display', 'lat': 37.76923879073783...      1225      94103
# 2   [{'label': 'display', 'lat': 37.7965779, 'lng'...      1959      94109
# 3   [{'label': 'display', 'lat': 37.76964417224087...      1266      94103
# 4   [{'label': 'display', 'lat': 37.77076041176799...      1230      94103
# 5   [{'label': 'display', 'lat': 37.75937356479043...      2557      94114
# 6   [{'label': 'display', 'lat': 37.78462493600286...      1322      94103
# 7   [{'label': 'display', 'lat': 37.788396, 'lng':...      1053      94109
# 8   [{'label': 'display', 'lat': 37.78761639932625...      2163      94105
# 9   [{'label': 'display', 'lat': 37.78832015506857...      2026      94105
# 10  [{'label': 'display', 'lat': 37.78337, 'lng': ...      1391      94103
# 11  [{'label': 'display', 'lat': 37.76761101243625...      1313      94103
# 12  [{'label': 'display', 'lat': 37.78636723353411...      1446      94103
# 13  [{'label': 'display', 'lat': 37.79031294360036...      1671      94108
# 14  [{'label': 'display', 'lat': 37.78886944537694...      1483      94102
# 15  [{'label': 'display', 'lat': 37.79225958986612...      1787      94108
# 16  [{'label': 'display', 'lat': 37.76503546402145...      1568      94103
# 17  [{'label': 'display', 'lat': 37.78375924658761...      1246      94115
# 18  [{'label': 'display', 'lat': 37.76118615249867...      1986      94110
# 19  [{'label': 'display', 'lat': 37.788166, 'lng':...      2089      94115
# 20  [{'label': 'display', 'lat': 37.77643018833841...       385      94103
# 21  [{'label': 'display', 'lat': 37.777614, 'lng':...       298      94102
# 22  [{'label': 'display', 'lat': 37.77987957394827...       268      94102
# 23  [{'label': 'display', 'lat': 37.78273499999999...       422      94102
# 24  [{'label': 'display', 'lat': 37.78238948486344...       382      94102
# 25  [{'label': 'display', 'lat': 37.79702800000000...      2249      94133
# 26  [{'label': 'display', 'lat': 37.794588, 'lng':...      2302      94111
# 27  [{'label': 'display', 'lat': 37.77511659319176...       459      94103
# 28  [{'label': 'display', 'lat': 37.77994, 'lng': ...       498        NaN
# 29  [{'label': 'display', 'lat': 37.7763557434082,...       470      94102
# 30  [{'label': 'display', 'lat': 37.77880498241423...       448      94102
# 13                             Food Fair Market Liquors
# 14                                      Sears Fine Food
# 15                                            Food-Nerd
# 16                                             Foodhall
# 17                                    Woori Food Market
# 18                                 Mission Chinese Food
# 19                                       Food Trattoria
# 20                              Food Trucks On Valencia
# 21                              Mad Will's Food Company
# 22                                       Super Sam Food
# 23                              Streets Eat Street Food
# 24                              Federal Bldg Food Court
# 25                                        IVYS Food Co,
# 26                                    Good Food Guys HQ
# 27                  Hongry Kong @ Soma StrEat Food Park
# 28                                 WoKitchen Food Truck
# 29           Taco Guys food truck @ Off The Grid: Proxy
# 30                             Ready To Nosh Food Tours
# 31                         Mercato Artisan Food & Gifts
# 32             Savourie Streets @ SOMA StrEat Food Park
# 33                                       Soul Food City
# 34                         Southeast Asian Food Product
# 35                                     Food And Wine SF
# 36                       Kim Hoang Coffee and Fast Food
# 37                 Brass Knuckle @ SOMA StreatFood Park
# 38                                      T&L Food Market
# 39                                    Chevron Food Mart
# 40                           Thali on Wheels Food Truck
# 41                        Nathan and Nathalie Fast Food
# 42                                  Food & Liquor World
# 43                              Kinder's BBQ Food Truck
# 44                                     Yogi Food Market
# 45                                   Veritas Food Truck
# 46                    Mama Cass @ Soma StrEat Food Park
# 47                          Little Henry's Italian Food
# 48                           Jeffrey's Natural Pet Food
# 49                               golden gate halal food
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_food = dataframe_filtered[['name','lat','lng']]
df_food.head()
# Out:
#                         name        lat         lng
# 0  Brenda's French Soul Food  37.782896 -122.418897
# 1           Pet Food Express  37.769239 -122.426271
# 2          Real Food Company  37.796578 -122.421632
# 3      SoMa StrEat Food Park  37.769644 -122.411755
# 4          Costco Food Court  37.770760 -122.410616

# %%
df_crime = df_incidents[['PdId','Y','X']]
df_crime.head(2)
# Out:
#              PdId          Y           X
# 3  16001366271000  37.785788 -122.412971
# 4  16000274071000  37.765050 -122.419672

# %%
pip install mpu
# Out:
# Requirement already satisfied: mpu in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.23.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
dist = pd.merge(df_crime.assign(k=1), df_food.assign(k=1), on='k', suffixes=('1', '2')) \
         .drop('k', axis=1)


dist.head()
# Out:
#              PdId          Y           X                       name  \
# 0  16001366271000  37.785788 -122.412971  Brenda's French Soul Food
# 1  16001366271000  37.785788 -122.412971           Pet Food Express
# 2  16001366271000  37.785788 -122.412971          Real Food Company
# 3  16001366271000  37.785788 -122.412971      SoMa StrEat Food Park
# 4  16001366271000  37.785788 -122.412971          Costco Food Court
#
#          lat         lng
# 0  37.782896 -122.418897
# 1  37.769239 -122.426271
# 2  37.796578 -122.421632
# 3  37.769644 -122.411755
# 4  37.770760 -122.410616

# %% [markdown]
# ##### We create a list of the distance for each crime and venue location

# %%
import mpu
lista = list()

# Point one
for Y,X,lat,lng in zip(dist.Y,dist.X,dist.lat,dist.lng):
    #i = 0
    lat1 = Y
    lon1 = X
    # Point two
    lat2 = lat
    lon2 = lng
    # What you were looking for

    lista.append(mpu.haversine_distance((lat1, lon1), (lat2, lon2)))

# %% [markdown]
# ##### We verify the list

# %%
#print("Values of a:", lista)
print("Size of a:", len(lista))
# Out:
# Size of a: 50000

# %%
df_distance = pd.DataFrame(lista,  columns =['Distance'])

# %%
df_distance.head()
# Out:
#    Distance
# 0  0.612127
# 1  2.180119
# 2  1.420800
# 3  1.798330
# 4  1.683800

# %% [markdown]
# ##### We concatenate the 2 dataframes

# %%
df_concat = pd.concat([dist, df_distance], axis=1)
df_concat.head()
# Out:
#              PdId          Y           X                       name  \
# 0  16001366271000  37.785788 -122.412971  Brenda's French Soul Food
# 1  16001366271000  37.785788 -122.412971           Pet Food Express
# 2  16001366271000  37.785788 -122.412971          Real Food Company
# 3  16001366271000  37.785788 -122.412971      SoMa StrEat Food Park
# 4  16001366271000  37.785788 -122.412971          Costco Food Court
#
#          lat         lng  Distance
# 0  37.782896 -122.418897  0.612127
# 1  37.769239 -122.426271  2.180119
# 2  37.796578 -122.421632  1.420800
# 3  37.769644 -122.411755  1.798330
# 4  37.770760 -122.410616  1.683800

# %%
df_final = df_concat.loc[df_concat.groupby("PdId")['Distance'].idxmin()]

# %%
df_final.head()
# Out:
#                  PdId          Y           X                           name  \
# 17369   1600360406304  37.779891 -122.467489                 Food Trattoria
# 7469   12072531805041  37.785229 -122.475505                 Food Trattoria
# 7519   12072531872000  37.785229 -122.475505                 Food Trattoria
# 38155  13019003071010  37.763312 -122.458221  Buffalo Whole Food & Grain Co
# 38205  13019003071012  37.763312 -122.458221  Buffalo Whole Food & Grain Co
#
#              lat         lng  Distance
# 17369  37.788166 -122.440650  2.531707
# 7469   37.788166 -122.440650  3.080322
# 7519   37.788166 -122.440650  3.080322
# 38155  37.759374 -122.434955  2.091637
# 38205  37.759374 -122.434955  2.091637

# %%
df_final.shape
# Out:
# (1000, 7)

# %%
food_data = df_final.groupby('name').count()
food_data.drop(columns=['Y','X','lat','lng','Distance'], inplace = True)

# %% [markdown]
# ##### At this moment we have the the closest venue for each crime, so now we need to know how many crimes for each venues

# %%
food_data.head()
# Out:
#                                       PdId
# name
# Brass Knuckle @ SOMA StreatFood Park     2
# Brenda's French Soul Food                3
# Buffalo Whole Food & Grain Co          179
# Caramba Mexican Food                    18
# Chevron Food Mart                        9

# %%
df_join = pd.merge(dataframe_filtered, food_data, left_on='name', right_on='name', how='left')
#.drop('name', axis=1)

# %% [markdown]
# ##### Now we join the 2 dataframe and have the crimes number by each venue

# %%
df_join = df_join.rename(columns={'PdId': 'Crimes'})
df_join.drop(columns=['labeledLatLngs','postalCode','cc','formattedAddress','neighborhood'], inplace = True)
#df_join['Crimes'] = df_join['Crimes'].astype(int64)
df_join.head(2)
# Out:
#                         name                       categories         address  \
# 0  Brenda's French Soul Food  Southern / Soul Food Restaurant     652 Polk St
# 1           Pet Food Express                        Pet Store  1975 Market St
#
#                   crossStreet        lat         lng  distance           city  \
# 0         btwn Eddy & Turk St  37.782896 -122.418897       439  San Francisco
# 1  (Between Duboce & Dolores)  37.769239 -122.426271      1225  San Francisco
#
#   state        country                        id  Crimes
# 0    CA  United States  49f356f8f964a5208a6a1fe3     3.0
# 1    CA  United States  4a3f0ce4f964a520aca31fe3    10.0

# %%
df_join = df_join.fillna(0)
df_join['Crimes'] = df_join['Crimes'].astype(np.int64)
df_join.dtypes
# Out:
# name            object
# categories      object
# address         object
# crossStreet     object
# lat            float64
# lng            float64
# distance         int64
# city            object
# state           object
# country         object
# id              object
# Crimes           int64
# dtype: object

# %%
df_join.head()
# Out:
#                         name                       categories         address  \
# 0  Brenda's French Soul Food  Southern / Soul Food Restaurant     652 Polk St
# 1           Pet Food Express                        Pet Store  1975 Market St
# 2          Real Food Company                  Organic Grocery    2140 Polk St
# 3      SoMa StrEat Food Park            Street Food Gathering     428 11th St
# 4          Costco Food Court                       Food Court     450 10th St
#
#                   crossStreet        lat         lng  distance           city  \
# 0         btwn Eddy & Turk St  37.782896 -122.418897       439  San Francisco
# 1  (Between Duboce & Dolores)  37.769239 -122.426271      1225  San Francisco
# 2                 at Broadway  37.796578 -122.421632      1959  San Francisco
# 3              at Division St  37.769644 -122.411755      1266  San Francisco
# 4              Near Bryant St  37.770760 -122.410616      1230  San Francisco
#
#   state        country                        id  Crimes
# 0    CA  United States  49f356f8f964a5208a6a1fe3       3
# 1    CA  United States  4a3f0ce4f964a520aca31fe3      10
# 2    CA  United States  49d7ae4bf964a5204b5d1fe3      20
# 3    CA  United States  4fc7c071e4b06e4ecff8e93d      13
# 4    CA  United States  52f934d711d2f1eaaa247732      10

# %%
venues_map_filter = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Sanfrancisco
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='San Franciso',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map_filter)

# add venues
for lat, lng, label in zip(df_join.lat, df_join.lng, df_join.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map_filter)

# display map
venues_map_filter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_join['marker_color'] = pd.cut(df_join['Crimes'], bins=3, 
                              labels=['green', 'orange', 'red'])
df_join.head(2)
# Out:
#                         name                       categories         address  \
# 0  Brenda's French Soul Food  Southern / Soul Food Restaurant     652 Polk St
# 1           Pet Food Express                        Pet Store  1975 Market St
#
#                   crossStreet        lat         lng  distance           city  \
# 0         btwn Eddy & Turk St  37.782896 -122.418897       439  San Francisco
# 1  (Between Duboce & Dolores)  37.769239 -122.426271      1225  San Francisco
#
#   state        country                        id  Crimes marker_color
# 0    CA  United States  49f356f8f964a5208a6a1fe3       3        green
# 1    CA  United States  4a3f0ce4f964a520aca31fe3      10        green

# %%
venues_map_filter = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around san francisco



import branca
import branca.colormap as cm

colormap = cm.LinearColormap(colors=['green','orange','red'], index=[2,10,189],vmin=0,vmax=189)

# add venues
for lat, lng, label,cri in zip(df_join.lat, df_join.lng, df_join.categories, df_join.Crimes):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color=colormap(cri),
        popup=label,
        fill = True,
        fill_color=colormap(cri),
        fill_opacity=0.6
    ).add_to(venues_map_filter)

# display map
venues_map_filter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### As we can see above we had a color marker depending on the number of crimes near the venue. When the color is green is becacause less crimes occure near this venue and when is red a lot of crimes near the venues

# %% [markdown]
# #### With this information the tourist can be more safe when visiting San Francisco
